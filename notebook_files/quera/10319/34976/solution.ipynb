# %% [markdown]
# فراخوانی ماژول‌های
# - `matplotlib` برای تصویر سازی داده
# - `pandas` برای کار با داده‌های جدولی
# - `numpy` برای انجام عملیات آرایه‌ای

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# فراخوانی داده‌ها با پانداس.

# %%
df_laliga = pd.read_csv('LaLiga_dataset.csv')

# %% [markdown]
# نمایش ۵ سطر اول داده.

# %%
df_laliga.head(5)
# Out:
#     season           club  home_win  away_win  home_loss  away_loss  \
# 0  1970-71  Real Zaragoza         3         0          5         13
# 1  1970-71          Elche         4         0          5         11
# 2  1970-71     Las Palmas         5         0          3         12
# 3  1970-71       Sabadell         8         0          3         14
# 4  1970-71       Espanyol         7         1          4          9
#
#    matches_won  matches_lost  matches_drawn  total_matches  points  \
# 0            3            18              9             30      18
# 1            4            16             10             30      22
# 2            5            15             10             30      25
# 3            8            17              5             30      29
# 4            8            13              9             30      33
#
#    home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 0          14           8            22              54              -32
# ...

# %% [markdown]
# نمایش ۷ سطر آخر داده.

# %%
df_laliga.tail(7)
# Out:
#       season                club  home_win  away_win  home_loss  away_loss  \
# 901  2016-17       Athletic Club        13         6          2         11
# 902  2016-17       Real Sociedad        10         9          4          8
# 903  2016-17          Villarreal        11         8          4          5
# 904  2016-17             Sevilla        14         7          1          7
# 905  2016-17  Atletico de Madrid        14         9          3          3
# 906  2016-17           Barcelona        15        13          1          3
# 907  2016-17         Real Madrid        14        15          1          2
#
#      matches_won  matches_lost  matches_drawn  total_matches  points  \
# 901           19            13              6             38      63
# 902           19            12              7             38      64
# 903           19             9             10             38      67
# 904           21             8              9             38      72
# ...

# %% [markdown]
# نمایش نوع ستون داده‌های فراخوانی شده.

# %%
df_laliga.dtypes
# Out:
# season             object
# club               object
# home_win            int64
# away_win            int64
# home_loss           int64
# away_loss           int64
# matches_won         int64
# matches_lost        int64
# matches_drawn       int64
# total_matches       int64
# points              int64
# home_goals          int64
# away_goals          int64
# goals_scored        int64
# goals_conceded      int64
# goal_difference     int64
# dtype: object

# %% [markdown]
# نمایش خلاصه‌های آماری ستون‌های عددی در داده.

# %%
df_laliga.describe()
# Out:
#          home_win    away_win   home_loss   away_loss  matches_won  \
# count  908.000000  908.000000  908.000000  908.000000   908.000000
# mean     9.582599    4.118943    4.118943    9.582599    13.701542
# std      3.107555    2.776725    2.531206    3.092974     4.966050
# min      1.000000    0.000000    0.000000    1.000000     2.000000
# 25%      7.000000    2.000000    2.000000    8.000000    10.000000
# 50%      9.000000    4.000000    4.000000   10.000000    13.000000
# 75%     12.000000    6.000000    6.000000   12.000000    16.000000
# max     19.000000   16.000000   15.000000   18.000000    32.000000
#
#        matches_lost  matches_drawn  total_matches      points  home_goals  \
# count    908.000000     908.000000     908.000000  908.000000  908.000000
# mean      13.701542       9.577093      36.980176   50.681718   29.508811
# std        4.589442       2.986852       2.522150   14.104626    9.757192
# ...

# %% [markdown]
# انتخاب فصل‌هایی در داده که تعداد تیم‌های برابر داشته اند.
# محاسبه‌ی مقدار امتیازهای هر فصل و ذخیره در آرایه‌ی نامپای.
# محاسبه‌ی دسته‌بندی‌های هیستوگرام بر اساس کل داده‌های مشاهده شده تا هیستوگرام تمامی نمودارهای دسته‌های یکسانی داشته باشند.
# نمایش هیستوگرام امتیاز نهایی تیم‌ها در انتهای دو فصل مختلف.

# %%
seasons = sorted(df_laliga['season'].unique())[-17:]
seasons = sorted(df_laliga['season'].unique())[-17::16]
points = np.zeros( ( len(seasons), 20 ) )
for i,season in enumerate(seasons):
    points[i] = df_laliga[ df_laliga['season'] == season ]['points'].values

points_min = np.min( points )
points_max = np.max( points )
bins = np.linspace(points_min,points_max,10)

plt.figure( figsize=(16,6), dpi = 300 )
plt.title('Histogram of Points: 2000 vs 2016')

for i,season in enumerate(seasons):
    plt.hist( points[i], bins = bins, alpha = 0.4, ec = 'black', label = season )
#
plt.ylabel('Number of Teams')
plt.xlabel('Points')
plt.legend()
plt.show()

# %%
laliga = df_laliga[['season','club','points']]
laliga
# Out:
#       season                club  points
# 0    1970-71       Real Zaragoza      18
# 1    1970-71               Elche      22
# 2    1970-71          Las Palmas      25
# 3    1970-71            Sabadell      29
# 4    1970-71            Espanyol      33
# ..       ...                 ...     ...
# 903  2016-17          Villarreal      67
# 904  2016-17             Sevilla      72
# 905  2016-17  Atletico de Madrid      78
# 906  2016-17           Barcelona      90
# 907  2016-17         Real Madrid      93
#
# [908 rows x 3 columns]

# %% [markdown]
# گرفتن جدول یک فصل از لالیگا

# %%
df_laliga[df_laliga['season'] == '1970-71'].sort_values("points",ascending=False).head(5)
# Out:
#      season                club  home_win  away_win  home_loss  away_loss  \
# 15  1970-71           Barcelona        11         8          3          3
# 14  1970-71            Valencia        12         6          1          4
# 13  1970-71  Atletico de Madrid        13         4          0          5
# 12  1970-71         Real Madrid        10         7          2          4
# 11  1970-71       Celta de Vigo        12         3          0         10
#
#     matches_won  matches_lost  matches_drawn  total_matches  points  \
# 15           19             6              5             30      62
# 14           18             5              7             30      61
# 13           17             5              8             30      59
# 12           17             6              7             30      58
# 11           15            10              5             30      50
#
#     home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# ...

# %% [markdown]
#  دو تابع
# `min_points(df_laliga,season)`
# و
# `max_points(df_laliga,season)`
# را کامل کنید و در فایل
# `functions.py`
# قرار دهید و ارسال کنید.

# %%
def min_points(df_laliga,season):
    laliga = df_laliga[['season','club','points']]
    laligaSeason = laliga.loc[laliga['season']==season]
    ans = laligaSeason[laligaSeason.points == laligaSeason.points.min()]
    ans = ans[['club','points']]
    ans = ans.to_dict('r')
    ans = ans[0]
    return ans

# %%
def max_points(df_laliga,season):
    laliga = df_laliga[['season','club','points']]
    laligaSeason = laliga.loc[laliga['season']==season]
    ans = laligaSeason[laligaSeason.points == laligaSeason.points.max()]
    ans= ans[['club','points']]
    ans= ans.to_dict('r')
    ans = ans[0]
    return ans

# %% [markdown]
# برای تست کردن توابع خود می‌توانید از دو سلول زیر استفاده کنید

# %%
min_points(df_laliga,'1997-98')
# Out:
# {'club': 'Sporting de Gijon', 'points': 13}

# %%
assert max_points(df_laliga,'1997-98') == {'club': 'Barcelona', 'points': 74}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-7c85f861a509> in <module>
# ----> 1 assert max_points(df_laliga,'1997-98') == {'club': 'Barcelona', 'points': 74}
#
# c:\users\reza\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# می‌توانید پس از تکمیل توابع و قرار دادن آنها در
# `functions.py`
# پس از ذخیره کردن نوت‌بوک،
# سلول زیر را اجرا کنید تا آنها را به همراه این نوت‌بوک زیپ کند.

# %%
import zlib
import zipfile


def compress(file_names):
    print("File Paths:")
    print(file_names)

    # Select the compression mode ZIP_DEFLATED for compression
    # or zipfile.ZIP_STORED to just store the file
    compression = zipfile.ZIP_DEFLATED

    # create the zip file first parameter path/name, second mode
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            # Add file to the zip file
            # first parameter file to zip, second filename in zip
            zf.write('./' + file_name, file_name, compress_type=compression)


file_names = ["functions.py", "solution.ipynb"]
compress(file_names)
